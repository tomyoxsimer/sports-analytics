# %%
### Assingment 8, Question 5 Thomas Yoxsimer ###
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics  
import pandas as pd
from sklearn import tree
import numpy as np
from matplotlib import pyplot as plt
from sklearn.naive_bayes import GaussianNB


import pandas as pd

df = pd.read_csv('week14.csv')

print('My Week 14 Picks')

#print(df)
df.replace('No', 0, inplace=True) # make everything binary
df.replace('Yes', 1, inplace=True)

pt = df['Picked Team']
opp = df['Opponent']
pick = df['Pick']
cover = df['Cover']
pw = df['Pick Wins']
pl = df['Pick Losses']
ow = df['Opponent Wins']
ol = df['Opponent Losses']


print('Succesful Picks vs over 500 teams:\n')


for (u, v, w, x, y, z) in zip(pick, opp, pt, cover, ow, ol):
    if x == 1 and y > z:
        print('\t', w, 'covered against', v, 'Pick:', u)


print('\nSuccesful Picks vs under 500 teams:\n')
for (u, v, w, x, y, z) in zip(pick, opp, pt, cover, ow, ol):
    if x == 1 and z > y:
        print('\t', w, 'covered against', v, 'Pick:', u)


print('\nSuccesful Picks with line below 4:\n')
for (u, v, w, x, y, z) in zip(pick, opp, pt, cover, ow, ol):
    if x == 1 and u <= 4:
        print('\t', w, 'covered against', v, 'Pick:', u)


print('\nSuccesful Picks with line above 4:\n')
for (u, v, w, x, y, z) in zip(pick, opp, pt, cover, ow, ol):
    if x == 1 and u >= 4:
        print('\t', w, 'covered against', v, 'Pick:', u)
        
        
for x in matchup_df['Home Team']:
    count2 = 0
    for y in teamlist_df['Team']:
        if x == y:
            print(x, y, teamlist_df.loc[count2, 'Above Average Rush O'])
        count += 1

#print(teamlist_df.loc[count2, 'Above Average Rush O'])
            #teamlist_df.iloc[]
            #print(pass_df.loc[x])
            #print(matchup_df['Home Team'].index(x))

#matchup_df['HT Above Average Rush O'] = matchdata


#for z in sorted_pass_df['Yds/G']:
#    sorted_pass_df['Yds/G'].replace(z, 1, inplace=True)

#for a,z in zip(pass_df['Yds/G'], sorted_pass_df['Yds/G']):
#    if float(a) != float(z):
#        sorted_pass_df['Yds/G'].replace(z, 0, inplace=True)
# Out:
# My Week 14 Picks
# Succesful Picks vs over 500 teams:
#
# 	 Dolphins covered against Chiefs Pick: 7.5
# 	 Steelers covered against Bills Pick: 1.5
#
# Succesful Picks vs under 500 teams:
#
# 	 Football Team covered against 49ers Pick: 4.5
#
# Succesful Picks with line below 4:
#
# 	 Colts covered against Raiders  Pick: -2.5
# 	 Steelers covered against Bills Pick: 1.5
#
# Succesful Picks with line above 4:
#
# 	 Dolphins covered against Chiefs Pick: 7.5
# 	 Football Team covered against 49ers Pick: 4.5
